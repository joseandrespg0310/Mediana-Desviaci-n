# %%
import pandas as pd

# Carga el archivo CSV usando una codificación alternativa
df = pd.read_csv("C:/Users/USUARIO/Downloads/Global_Education.csv", encoding='ISO-8859-1')

# %%
# Calcula  estadisticos descriptivos
df.describe()
# Out:
#         Latitude    Longitude  OOSR_Pre0Primary_Age_Male  \
# count  202.000000  202.000000                 202.000000
# mean    25.081422   55.166928                  19.658416
# std     16.813639   45.976287                  25.007604
# min      0.023559    0.824782                   0.000000
# 25%     11.685062   18.665678                   0.000000
# 50%     21.207861   43.518091                   9.000000
# 75%     39.901792   77.684945                  31.000000
# max     64.963051  178.065032                  96.000000
#
#        OOSR_Pre0Primary_Age_Female  OOSR_Primary_Age_Male  \
# count                   202.000000             202.000000
# mean                     19.282178               5.282178
# std                      25.171147               9.396442
# min                       0.000000               0.000000
# 25%                       0.000000               0.000000
# 50%                       7.000000               1.000000
# ...

# %% [markdown]
# # Calcular la mediana

# %%
median = df.median(numeric_only=True)
print("Mediana:\n", median)
# Out:
# Mediana:
#  Latitude                                    21.207861
# Longitude                                   43.518091
# OOSR_Pre0Primary_Age_Male                    9.000000
# OOSR_Pre0Primary_Age_Female                  7.000000
# OOSR_Primary_Age_Male                        1.000000
# OOSR_Primary_Age_Female                      1.000000
# OOSR_Lower_Secondary_Age_Male                2.000000
# OOSR_Lower_Secondary_Age_Female              2.000000
# OOSR_Upper_Secondary_Age_Male               15.000000
# OOSR_Upper_Secondary_Age_Female             12.000000
# Completion_Rate_Primary_Male                37.500000
# Completion_Rate_Primary_Female              33.000000
# Completion_Rate_Lower_Secondary_Male        18.500000
# Completion_Rate_Lower_Secondary_Female      12.000000
# Completion_Rate_Upper_Secondary_Male         9.500000
# Completion_Rate_Upper_Secondary_Female       5.500000
# Grade_2_3_Proficiency_Reading                0.000000
# ...

# %% [markdown]
# # Calcular Desviacion Estandar

# %%
std_dev = df.std(numeric_only=True)
print("Desviación estándar:\n", std_dev)
# Out:
# Desviación estándar:
#  Latitude                                   16.813639
# Longitude                                  45.976287
# OOSR_Pre0Primary_Age_Male                  25.007604
# OOSR_Pre0Primary_Age_Female                25.171147
# OOSR_Primary_Age_Male                       9.396442
# OOSR_Primary_Age_Female                    10.383092
# OOSR_Lower_Secondary_Age_Male              13.258203
# OOSR_Lower_Secondary_Age_Female            14.724717
# OOSR_Upper_Secondary_Age_Male              21.485592
# OOSR_Upper_Secondary_Age_Female            23.140376
# Completion_Rate_Primary_Male               42.162708
# Completion_Rate_Primary_Female             43.099714
# Completion_Rate_Lower_Secondary_Male       36.438123
# Completion_Rate_Lower_Secondary_Female     38.040452
# Completion_Rate_Upper_Secondary_Male       28.604850
# Completion_Rate_Upper_Secondary_Female     30.487827
# Grade_2_3_Proficiency_Reading              34.873326
# ...
